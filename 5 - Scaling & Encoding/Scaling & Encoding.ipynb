# %% [markdown]
# ## Scaling & Encoding Data

# %%
import pandas as pd

df = pd.read_parquet("../0 - Data/featured_transactions.pq")
df.head()
# Out:
#    Amount          Use Chip   MCC  Card Brand        Card Type  Has Chip  \
# 0  130.95  Chip Transaction  5912        Visa            Debit         1
# 1  130.95  Chip Transaction  5912        Visa            Debit         1
# 2  130.95  Chip Transaction  5912        Visa            Debit         1
# 3  130.95  Chip Transaction  5912        Visa           Credit         0
# 4  130.95  Chip Transaction  5912  Mastercard  Debit (Prepaid)         1
#
#    Cards Issued  Credit Limit Acct Open Date  Year PIN last Changed  ...  \
# 0             2       24295.0     2002-09-01                   2008  ...
# 1             2       21968.0     2014-04-01                   2014  ...
# 2             2       46414.0     2003-07-01                   2004  ...
# 3             1       12400.0     2003-01-01                   2012  ...
# 4             1          28.0     2008-09-01                   2009  ...
#
#    Transaction Hour  Transaction Day  Transaction Month  \
# 0                 6                2                  1
# 1                 6                2                  1
# 2                 6                2                  1
# 3                 6                2                  1
# 4                 6                2                  1
#
#    Transaction Day of Week Is Weekend  Account Age (Days)  \
# 0                        1          0                5602
# 1                        1          0                1372
# 2                        1          0                5299
# 3                        1          0                5480
# 4                        1          0                3410
#
#    Debt to Income Ratio  Credit Utilization  Age Group  Is Retired
# 0              2.137714            0.005390      46-60       False
# 1              2.137714            0.005961      46-60       False
# 2              2.137714            0.002821      46-60       False
# 3              2.137714            0.010560      46-60       False
# 4              2.137714            4.676786      46-60       False
#
# [5 rows x 34 columns]

# %% [markdown]
# #### Drop any Left Over Columns

# %%
datetime_columns = df.select_dtypes(include=['datetime']).columns
string_columns = df.dtypes[df.dtypes == 'object'].index

print("Datetime columns:", datetime_columns)
print("String columns:", string_columns)
# Out:
# Datetime columns: Index(['Acct Open Date', 'Datetime'], dtype='object')
# String columns: Index(['Use Chip', 'Card Brand', 'Card Type', 'Gender'], dtype='object')

# %%
df = df.drop(["Acct Open Date"], axis=1)
df.head()
# Out:
#    Amount          Use Chip   MCC  Card Brand        Card Type  Has Chip  \
# 0  130.95  Chip Transaction  5912        Visa            Debit         1
# 1  130.95  Chip Transaction  5912        Visa            Debit         1
# 2  130.95  Chip Transaction  5912        Visa            Debit         1
# 3  130.95  Chip Transaction  5912        Visa           Credit         0
# 4  130.95  Chip Transaction  5912  Mastercard  Debit (Prepaid)         1
#
#    Cards Issued  Credit Limit  Year PIN last Changed  Current Age  ...  \
# 0             2       24295.0                   2008           53  ...
# 1             2       21968.0                   2014           53  ...
# 2             2       46414.0                   2004           53  ...
# 3             1       12400.0                   2012           53  ...
# 4             1          28.0                   2009           53  ...
#
#    Transaction Hour  Transaction Day  Transaction Month  \
# 0                 6                2                  1
# 1                 6                2                  1
# 2                 6                2                  1
# 3                 6                2                  1
# 4                 6                2                  1
#
#   Transaction Day of Week  Is Weekend  Account Age (Days)  \
# 0                       1           0                5602
# 1                       1           0                1372
# 2                       1           0                5299
# 3                       1           0                5480
# 4                       1           0                3410
#
#    Debt to Income Ratio  Credit Utilization  Age Group  Is Retired
# 0              2.137714            0.005390      46-60       False
# 1              2.137714            0.005961      46-60       False
# 2              2.137714            0.002821      46-60       False
# 3              2.137714            0.010560      46-60       False
# 4              2.137714            4.676786      46-60       False
#
# [5 rows x 33 columns]

# %% [markdown]
# #### One-Hot Encoding Categorical Features

# %%
df = pd.get_dummies(df, columns=['Card Brand', 'Card Type', 'Gender', 'Age Group', 'Use Chip'], drop_first=True)
df.head()
# Out:
#    Amount   MCC  Has Chip  Cards Issued  Credit Limit  Year PIN last Changed  \
# 0  130.95  5912         1             2       24295.0                   2008
# 1  130.95  5912         1             2       21968.0                   2014
# 2  130.95  5912         1             2       46414.0                   2004
# 3  130.95  5912         0             1       12400.0                   2012
# 4  130.95  5912         1             1          28.0                   2009
#
#    Current Age  Retirement Age  Birth Year  Birth Month  ...  Card Brand_Visa  \
# 0           53              66        1966           11  ...             True
# 1           53              66        1966           11  ...             True
# 2           53              66        1966           11  ...             True
# 3           53              66        1966           11  ...             True
# 4           53              66        1966           11  ...            False
#
#    Card Type_Debit  Card Type_Debit (Prepaid)  Gender_Male  Age Group_26-35  \
# 0             True                      False        False            False
# 1             True                      False        False            False
# 2             True                      False        False            False
# 3            False                      False        False            False
# 4            False                       True        False            False
#
#    Age Group_36-45  Age Group_46-60 Age Group_60+  \
# 0            False             True         False
# 1            False             True         False
# 2            False             True         False
# 3            False             True         False
# 4            False             True         False
#
#    Use Chip_Online Transaction  Use Chip_Swipe Transaction
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
#
# [5 rows x 40 columns]

# %% [markdown]
# #### Check for any Accidental Infinity in Extracted Features

# %%
import numpy as np

numeric_columns = df.select_dtypes(include=['number']).columns

unsafe_cols = []
for column in numeric_columns:
    maximum = df[column].max()
    if not maximum < np.inf: unsafe_cols.append(column)

print(f"Unsafe Columns: {unsafe_cols}")
# Out:
# Unsafe Columns: ['Credit Utilization']

# %%
# Handle unsafe values
df["Credit Utilization"] = df["Credit Utilization"].replace([np.inf, -np.inf], 1)

# %% [markdown]
# #### Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Save the target variable (We dont want to scale this one)
target = df["Is Fraud"]
numeric_columns = numeric_columns.drop("Is Fraud")

# Scale the data
df_without_target = df.drop(["Is Fraud"], axis=1)
df_without_target[numeric_columns] = scaler.fit_transform(df_without_target[numeric_columns])

# Append the target column back
df_scaled = df_without_target.copy()
df_scaled["Is Fraud"] = target

df_scaled.head()
# Out:
#      Amount       MCC  Has Chip  Cards Issued  Credit Limit  \
# 0  1.112768  0.389974  0.337145      0.963448      0.738314
# 1  1.112768  0.389974  0.337145      0.963448      0.551106
# 2  1.112768  0.389974  0.337145      0.963448      2.517794
# 3  1.112768  0.389974 -2.966079     -0.967922     -0.218642
# 4  1.112768  0.389974  0.337145     -0.967922     -1.213973
#
#    Year PIN last Changed  Current Age  Retirement Age  Birth Year  \
# 0              -1.215831     -0.09811       -0.185577    0.087548
# 1               0.399826     -0.09811       -0.185577    0.087548
# 2              -2.292935     -0.09811       -0.185577    0.087548
# 3              -0.138727     -0.09811       -0.185577    0.087548
# 4              -0.946555     -0.09811       -0.185577    0.087548
#
#    Birth Month  ...  Card Type_Debit  Card Type_Debit (Prepaid)  Gender_Male  \
# 0     1.250378  ...             True                      False        False
# 1     1.250378  ...             True                      False        False
# 2     1.250378  ...             True                      False        False
# 3     1.250378  ...            False                      False        False
# 4     1.250378  ...            False                       True        False
#
#    Age Group_26-35  Age Group_36-45  Age Group_46-60  Age Group_60+  \
# 0            False            False             True          False
# 1            False            False             True          False
# 2            False            False             True          False
# 3            False            False             True          False
# 4            False            False             True          False
#
#   Use Chip_Online Transaction  Use Chip_Swipe Transaction  Is Fraud
# 0                       False                       False         0
# 1                       False                       False         0
# 2                       False                       False         0
# 3                       False                       False         0
# 4                       False                       False         0
#
# [5 rows x 40 columns]

# %% [markdown]
# #### Save the Scaled Data

# %%
df.to_parquet("../0 - Data/scaled_transactions.pq")
