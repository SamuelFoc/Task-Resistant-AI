# %% [markdown]
# ## Scaling & Encoding Data (Strategy 1)
#
# - Encoding MCCs each as own column

# %%
import pandas as pd

df = pd.read_parquet("../0 - Data/3 - featured/ft_strategy_1.pq")
df.head()
# Out:
#       Amount           Use Chip   MCC        Card Type  Has Chip  \
# 6780  123.97  Swipe Transaction  5541            Debit         1
# 6781  123.97  Swipe Transaction  5541            Debit         1
# 6782  123.97  Swipe Transaction  5541            Debit         1
# 6783  123.97  Swipe Transaction  5541           Credit         0
# 6784  123.97  Swipe Transaction  5541  Debit (Prepaid)         1
#
#       Cards Issued  Credit Limit  Current Age  Retirement Age  Gender  ...  \
# 6780             2       24295.0           53              66  Female  ...
# 6781             2       21968.0           53              66  Female  ...
# 6782             2       46414.0           53              66  Female  ...
# 6783             1       12400.0           53              66  Female  ...
# 6784             1          28.0           53              66  Female  ...
#
#       AmountToCreditLimitRatio  IncomeToSpendingRatioZip  \
# 6780                  0.005103                236.170041
# 6781                  0.005643                236.170041
# 6782                  0.002671                236.170041
# 6783                  0.009998                236.170041
# 6784                  4.427500                236.170041
#
#       IncomeToSpendingRatioPerson  DebtToIncomeRatio  CardUsageRatio  \
# 6780                   481.535855           2.137714             2.5
# 6781                   481.535855           2.137714             2.5
# 6782                   481.535855           2.137714             2.5
# 6783                   481.535855           2.137714             5.0
# 6784                   481.535855           2.137714             5.0
#
#       YearsToRetirement  Account Age (Days) Age Group  Is Retired  \
# 6780                 13                5601     46-60       False
# 6781                 13                1371     46-60       False
# 6782                 13                5298     46-60       False
# 6783                 13                5479     46-60       False
# 6784                 13                3409     46-60       False
#
#       Bad PIN Error
# 6780          False
# 6781          False
# 6782          False
# 6783          False
# 6784          False
#
# [5 rows x 35 columns]

# %% [markdown]
# #### Find columns that needs to be encoded

# %%
columns_to_encode = df.select_dtypes(include=['category', 'object']).columns

print("Columns that need encoding:", columns_to_encode)
# Out:
# Columns that need encoding: Index(['Use Chip', 'Card Type', 'Gender', 'Age Group'], dtype='object')

# %% [markdown]
# #### One-Hot Encoding Categorical Features

# %%
df = pd.get_dummies(df, columns=columns_to_encode, drop_first=True)
df.head(2)
# Out:
#       Amount   MCC  Has Chip  Cards Issued  Credit Limit  Current Age  \
# 6780  123.97  5541         1             2       24295.0           53
# 6781  123.97  5541         1             2       21968.0           53
#
#       Retirement Age  Latitude  Longitude  Per Capita Income - Zipcode  ...  \
# 6780              66     34.15    -117.76                      29278.0  ...
# 6781              66     34.15    -117.76                      29278.0  ...
#
#       Bad PIN Error  Use Chip_Online Transaction  Use Chip_Swipe Transaction  \
# 6780          False                        False                        True
# 6781          False                        False                        True
#
#       Card Type_Debit Card Type_Debit (Prepaid)  Gender_Male  Age Group_26-35  \
# 6780             True                     False        False            False
# 6781             True                     False        False            False
#
#       Age Group_36-45  Age Group_46-60  Age Group_60+
# 6780            False             True          False
# 6781            False             True          False
#
# [2 rows x 40 columns]

# %% [markdown]
# #### One Hot Encode MCC

# %%
df = pd.get_dummies(df, columns=["MCC"], drop_first=True)
df.head(2)
# Out:
#       Amount  Has Chip  Cards Issued  Credit Limit  Current Age  \
# 6780  123.97         1             2       24295.0           53
# 6781  123.97         1             2       21968.0           53
#
#       Retirement Age  Latitude  Longitude  Per Capita Income - Zipcode  \
# 6780              66     34.15    -117.76                      29278.0
# 6781              66     34.15    -117.76                      29278.0
#
#       Yearly Income - Person  ...  MCC_8011  MCC_8021  MCC_8041 MCC_8043  \
# 6780                 59696.0  ...     False     False     False    False
# 6781                 59696.0  ...     False     False     False    False
#
#       MCC_8049  MCC_8062  MCC_8099  MCC_8111  MCC_8931  MCC_9402
# 6780     False     False     False     False     False     False
# 6781     False     False     False     False     False     False
#
# [2 rows x 147 columns]

# %% [markdown]
# #### Check for any Accidental Infinity in Extracted Features

# %%
import numpy as np

numeric_columns = df.select_dtypes(include=['number']).columns

unsafe_cols = []
for column in numeric_columns:
    maximum = df[column].max()
    if not maximum < np.inf: unsafe_cols.append(column)

print(f"Unsafe Columns: {unsafe_cols}")
# Out:
# Unsafe Columns: []

# %%
# Handle unsafe values if any

# %% [markdown]
# #### Scale

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Save the target variable (We dont want to scale this one)
target = df["Is Fraud"]
numeric_columns = numeric_columns.drop("Is Fraud")

# Scale the data
df_without_target = df.drop(["Is Fraud"], axis=1)
df_without_target[numeric_columns] = scaler.fit_transform(df_without_target[numeric_columns])

# Append the target column back
df_scaled = df_without_target.copy()
df_scaled["Is Fraud"] = target

df_scaled.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 14
#      11 df_without_target[numeric_columns] = scaler.fit_transform(df_without_target[numeric_columns])
#      13 # Append the target column back
# ---> 14 df_scaled = df_without_target.copy()
#      15 df_scaled["Is Fraud"] = target
#      17 df_scaled.head()
#
# File c:\Users\ssipikal\Desktop\resistant\.venv\lib\site-packages\pandas\core\generic.py:6811, in NDFrame.copy(self, deep)
#    6662 @final
#    6663 def copy(self, deep: bool_t | None = True) -> Self:
#    6664     """
#    6665     Make a copy of this object's indices and data.
#    6666
#    (...)
#    6809     dtype: int64
#    6810     """
# -> 6811     data = self._mgr.copy(deep=deep)
#    6812     self._clear_item_cache()
#    6813     return self._constructor_from_mgr(data, axes=data.axes).__finalize__(
#    6814         self, method="copy"
#    6815     )
#
# File c:\Users\ssipikal\Desktop\resistant\.venv\lib\site-packages\pandas\core\internals\managers.py:604, in BaseBlockManager.copy(self, deep)
#     601         res._blklocs = self._blklocs.copy()
#     603 if deep:
# --> 604     res._consolidate_inplace()
#     605 return res
#
# File c:\Users\ssipikal\Desktop\resistant\.venv\lib\site-packages\pandas\core\internals\managers.py:1788, in BlockManager._consolidate_inplace(self)
#    1782 def _consolidate_inplace(self) -> None:
#    1783     # In general, _consolidate_inplace should only be called via
#    1784     #  DataFrame._consolidate_inplace, otherwise we will fail to invalidate
#    1785     #  the DataFrame's _item_cache. The exception is for newly-created
#    1786     #  BlockManager objects not yet attached to a DataFrame.
#    1787     if not self.is_consolidated():
# -> 1788         self.blocks = _consolidate(self.blocks)
#    1789         self._is_consolidated = True
#    1790         self._known_consolidated = True
#
# File c:\Users\ssipikal\Desktop\resistant\.venv\lib\site-packages\pandas\core\internals\managers.py:2269, in _consolidate(blocks)
#    2267 new_blocks: list[Block] = []
#    2268 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2269     merged_blocks, _ = _merge_blocks(
#    2270         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2271     )
#    2272     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2273 return tuple(new_blocks)
#
# File c:\Users\ssipikal\Desktop\resistant\.venv\lib\site-packages\pandas\core\internals\managers.py:2301, in _merge_blocks(blocks, dtype, can_consolidate)
#    2298     new_values = bvals2[0]._concat_same_type(bvals2, axis=0)
#    2300 argsort = np.argsort(new_mgr_locs)
# -> 2301 new_values = new_values[argsort]
#    2302 new_mgr_locs = new_mgr_locs[argsort]
#    2304 bp = BlockPlacement(new_mgr_locs)
#
# MemoryError: Unable to allocate 2.60 GiB for an array with shape (26, 13412376) and data type float64

# %% [markdown]
# #### Append Non Scaling Values

# %%
# Append the target and datetime columns back
df_scaled["Is Fraud"] = target.values

df_scaled.head()
# Out:
#         Amount  Has Chip  Cards Issued  Credit Limit  Current Age  \
# 6780  1.025128  0.337145      0.963448      0.738314     -0.09811
# 6781  1.025128  0.337145      0.963448      0.551106     -0.09811
# 6782  1.025128  0.337145      0.963448      2.517794     -0.09811
# 6783  1.025128 -2.966079     -0.967922     -0.218642     -0.09811
# 6784  1.025128  0.337145     -0.967922     -1.213973     -0.09811
#
#       Retirement Age  Latitude  Longitude  Per Capita Income - Zipcode  \
# 6780       -0.185577 -0.631234  -1.563208                     0.447753
# 6781       -0.185577 -0.631234  -1.563208                     0.447753
# 6782       -0.185577 -0.631234  -1.563208                     0.447753
# 6783       -0.185577 -0.631234  -1.563208                     0.447753
# 6784       -0.185577 -0.631234  -1.563208                     0.447753
#
#       Yearly Income - Person  ...  MCC_8021  MCC_8041  MCC_8043 MCC_8049  \
# 6780                0.559483  ...     False     False     False    False
# 6781                0.559483  ...     False     False     False    False
# 6782                0.559483  ...     False     False     False    False
# 6783                0.559483  ...     False     False     False    False
# 6784                0.559483  ...     False     False     False    False
#
#       MCC_8062  MCC_8099  MCC_8111  MCC_8931  MCC_9402  Is Fraud
# 6780     False     False     False     False     False         0
# 6781     False     False     False     False     False         0
# 6782     False     False     False     False     False         0
# 6783     False     False     False     False     False         0
# 6784     False     False     False     False     False         0
#
# [5 rows x 147 columns]

# %% [markdown]
# #### Save the Scaled Data

# %%
import os

clean_dir = "../0 - Data/4 - scaled"
if not os.path.exists(clean_dir):
    os.makedirs(clean_dir)

df_scaled.to_parquet("../0 - Data/4 - scaled/ft_strategy_1_scaled.pq")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 if not os.path.exists(clean_dir):
#       5     os.makedirs(clean_dir)
# ----> 7 df_scaled.to_parquet("../0 - Data/4 - scaled/ft_strategy_1_scaled.pq")
#
# NameError: name 'df_scaled' is not defined
