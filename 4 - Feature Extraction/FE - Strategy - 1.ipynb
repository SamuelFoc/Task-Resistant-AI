# %% [markdown]
# ## FE - Strategy - 1
#
# #### INFO
#
# - End Columns: 35
# - Extracted Features: 16
#     - Hour
#     - DayOfWeek
#     - MonthOfYear
#     - TimeSinceLastTransaction
#     - AvgTransactionAmountWeek
#     - AvgTransactionAmountMonth
#     - AmountToCreditLimitRatio
#     - IncomeToSpendingRatioZip
#     - IncomeToSpendingRatioPerson
#     - DebtToIncomeRatio
#     - CardUsageRatio
#     - YearsToRetirement
#     - Account Age (Days)
#     - Age Group
#     - Is Retired
#     - Bad PIN Error

# %%
import pandas as pd
import numpy as np

original_df = pd.read_parquet("../0 - Data/2 - Clean/clean_transactions.pq")
original_df.head(2)
# Out:
#    User  Card  Year  Month  Day  Amount          Use Chip  \
# 0     0     0  2018      1    2  130.95  Chip Transaction
# 1     0     0  2018      1    2  130.95  Chip Transaction
#
#          Merchant Name Merchant City Merchant State  ... Zipcode  Latitude  \
# 0  5817218446178736267      La Verne             CA  ...   91750     34.15
# 1  5817218446178736267      La Verne             CA  ...   91750     34.15
#
#   Longitude  Per Capita Income - Zipcode Yearly Income - Person Total Debt  \
# 0   -117.76                      29278.0                59696.0   127613.0
# 1   -117.76                      29278.0                59696.0   127613.0
#
#    FICO Score Num Credit Cards            Datetime  Is Fraud
# 0         787                5 2018-01-02 06:28:00         0
# 1         787                5 2018-01-02 06:28:00         0
#
# [2 rows x 45 columns]

# %% [markdown]
# Drop Columns with Low Correlation to Fraud

# %%
# Columns to drop
columns_to_drop = [ "Merchant City", "Merchant State", "Year", "Month", "Day", "Person", "Zip", "CARD INDEX", "Card Number", 
    "CVV", "Expires", "Address", "Apartment", "City", "State", "Zipcode", "Card on Dark Web"
]

df = original_df.drop(columns_to_drop, axis=1)
df.head(2)
# Out:
#    User  Card  Amount          Use Chip        Merchant Name   MCC Errors?  \
# 0     0     0  130.95  Chip Transaction  5817218446178736267  5912       0
# 1     0     0  130.95  Chip Transaction  5817218446178736267  5912       0
#
#   Card Brand Card Type  Has Chip  ...  Gender  Latitude Longitude  \
# 0       Visa     Debit         1  ...  Female     34.15   -117.76
# 1       Visa     Debit         1  ...  Female     34.15   -117.76
#
#    Per Capita Income - Zipcode  Yearly Income - Person  Total Debt  \
# 0                      29278.0                 59696.0    127613.0
# 1                      29278.0                 59696.0    127613.0
#
#    FICO Score  Num Credit Cards            Datetime  Is Fraud
# 0         787                 5 2018-01-02 06:28:00         0
# 1         787                 5 2018-01-02 06:28:00         0
#
# [2 rows x 28 columns]

# %% [markdown]
# Time Based Features

# %%
# Convert to datetime if not already done
df['Datetime'] = pd.to_datetime(df['Datetime'], errors='coerce')

# Extract hour, day of the week, and month
df['Hour'] = df['Datetime'].dt.hour
df['DayOfWeek'] = df['Datetime'].dt.dayofweek  # Monday=0, Sunday=6
df['MonthOfYear'] = df['Datetime'].dt.month

# %% [markdown]
# Time Since the Last Transaction

# %%
df = df.sort_values(['User', 'Datetime'])
df['TimeSinceLastTransaction'] = df.groupby('User')['Datetime'].diff().dt.total_seconds() / 60  # in minutes
df['TimeSinceLastTransaction'] = df['TimeSinceLastTransaction'].fillna(0)

df.head(2)
# Out:
#       User  Card  Amount           Use Chip        Merchant Name   MCC  \
# 6780     0     3  123.97  Swipe Transaction  2027553650310142703  5541
# 6781     0     3  123.97  Swipe Transaction  2027553650310142703  5541
#
#      Errors? Card Brand Card Type  Has Chip  ...  Yearly Income - Person  \
# 6780       0       Visa     Debit         1  ...                 59696.0
# 6781       0       Visa     Debit         1  ...                 59696.0
#
#       Total Debt FICO Score  Num Credit Cards            Datetime  Is Fraud  \
# 6780    127613.0        787                 5 2018-01-01 05:36:00         0
# 6781    127613.0        787                 5 2018-01-01 05:36:00         0
#
#       Hour  DayOfWeek MonthOfYear  TimeSinceLastTransaction
# 6780     5          0           1                       0.0
# 6781     5          0           1                       0.0
#
# [2 rows x 32 columns]

# %% [markdown]
# AVG Transaction Amount / Week / Month

# %%
df['AvgTransactionAmountWeek'] = df.groupby('User')['Amount'].transform(lambda x: x.rolling(window=7, min_periods=1).mean())
df['AvgTransactionAmountMonth'] = df.groupby('User')['Amount'].transform(lambda x: x.rolling(window=30, min_periods=1).mean())

df.head(2)
# Out:
#       User  Card  Amount           Use Chip        Merchant Name   MCC  \
# 6780     0     3  123.97  Swipe Transaction  2027553650310142703  5541
# 6781     0     3  123.97  Swipe Transaction  2027553650310142703  5541
#
#      Errors? Card Brand Card Type  Has Chip  ...  FICO Score  \
# 6780       0       Visa     Debit         1  ...         787
# 6781       0       Visa     Debit         1  ...         787
#
#       Num Credit Cards            Datetime  Is Fraud  Hour  DayOfWeek  \
# 6780                 5 2018-01-01 05:36:00         0     5          0
# 6781                 5 2018-01-01 05:36:00         0     5          0
#
#       MonthOfYear  TimeSinceLastTransaction AvgTransactionAmountWeek  \
# 6780            1                       0.0                   123.97
# 6781            1                       0.0                   123.97
#
#       AvgTransactionAmountMonth
# 6780                     123.97
# 6781                     123.97
#
# [2 rows x 34 columns]

# %% [markdown]
# Transaction Amount to Credit Card Limit Ratio

# %%
def handle_inf(col: str):
    df[col] = df[col].replace([np.inf, -np.inf], np.nan)
    max_ratio = df[col].max()
    df[col] = df[col].replace(np.nan, max_ratio)

df['AmountToCreditLimitRatio'] = df['Amount'] / df['Credit Limit']
handle_inf("AmountToCreditLimitRatio")

# %% [markdown]
# Income to Spendings Ratio / Zipcode / Person

# %%
df['IncomeToSpendingRatioZip'] = df['Per Capita Income - Zipcode'] / df['Amount']
handle_inf('IncomeToSpendingRatioZip')

df['IncomeToSpendingRatioPerson'] = df['Yearly Income - Person'] / df['Amount']
handle_inf('IncomeToSpendingRatioPerson')

# %% [markdown]
# Debt to Incom Ratio

# %%
df['DebtToIncomeRatio'] = df['Total Debt'] / df['Yearly Income - Person']

# %% [markdown]
# Cards Usage Ratio

# %%
df['CardUsageRatio'] = df['Num Credit Cards'] / df['Cards Issued']

# %% [markdown]
# Years to Retirement

# %%
df['YearsToRetirement'] = df['Retirement Age'] - df['Current Age']

# %% [markdown]
# Account Age

# %%
df['Acct Open Date'] = pd.to_datetime(df['Acct Open Date'])

df['Account Age (Days)'] = (df['Datetime'] - df['Acct Open Date']).dt.days

# %% [markdown]
# Age Groups

# %%
df['Age Group'] = pd.cut(df['Current Age'], bins=[0, 25, 35, 45, 60, 100], labels=['18-25', '26-35', '36-45', '46-60', '60+'])

# %% [markdown]
# Retirement

# %%
df['Is Retired'] = df['Current Age'] >= df['Retirement Age']

df.head()
# Out:
#       User  Card  Amount           Use Chip        Merchant Name   MCC  \
# 6780     0     3  123.97  Swipe Transaction  2027553650310142703  5541
# 6781     0     3  123.97  Swipe Transaction  2027553650310142703  5541
# 6782     0     3  123.97  Swipe Transaction  2027553650310142703  5541
# 6783     0     3  123.97  Swipe Transaction  2027553650310142703  5541
# 6784     0     3  123.97  Swipe Transaction  2027553650310142703  5541
#
#      Errors?  Card Brand        Card Type  Has Chip  ...  \
# 6780       0        Visa            Debit         1  ...
# 6781       0        Visa            Debit         1  ...
# 6782       0        Visa            Debit         1  ...
# 6783       0        Visa           Credit         0  ...
# 6784       0  Mastercard  Debit (Prepaid)         1  ...
#
#       AvgTransactionAmountMonth  AmountToCreditLimitRatio  \
# 6780                     123.97                  0.005103
# 6781                     123.97                  0.005643
# 6782                     123.97                  0.002671
# 6783                     123.97                  0.009998
# 6784                     123.97                  4.427500
#
#      IncomeToSpendingRatioZip  IncomeToSpendingRatioPerson  DebtToIncomeRatio  \
# 6780               236.170041                   481.535855           2.137714
# 6781               236.170041                   481.535855           2.137714
# 6782               236.170041                   481.535855           2.137714
# 6783               236.170041                   481.535855           2.137714
# 6784               236.170041                   481.535855           2.137714
#
#       CardUsageRatio  YearsToRetirement  Account Age (Days) Age Group  \
# 6780             2.5                 13                5601     46-60
# 6781             2.5                 13                1371     46-60
# 6782             2.5                 13                5298     46-60
# 6783             5.0                 13                5479     46-60
# 6784             5.0                 13                3409     46-60
#
#       Is Retired
# 6780       False
# 6781       False
# 6782       False
# 6783       False
# 6784       False
#
# [5 rows x 43 columns]

# %% [markdown]
# Is Bad PIN in Errors

# %%
df['Bad PIN Error'] = df['Errors?'] == "Bad PIN"

# %% [markdown]
# Select the columns to drop

# %%
df.columns
# Out:
# Index(['User', 'Card', 'Amount', 'Use Chip', 'Merchant Name', 'MCC', 'Errors?',
#        'Card Brand', 'Card Type', 'Has Chip', 'Cards Issued', 'Credit Limit',
#        'Acct Open Date', 'Year PIN last Changed', 'Current Age',
#        'Retirement Age', 'Birth Year', 'Birth Month', 'Gender', 'Latitude',
#        'Longitude', 'Per Capita Income - Zipcode', 'Yearly Income - Person',
#        'Total Debt', 'FICO Score', 'Num Credit Cards', 'Datetime', 'Is Fraud',
#        'Hour', 'DayOfWeek', 'MonthOfYear', 'TimeSinceLastTransaction',
#        'AvgTransactionAmountWeek', 'AvgTransactionAmountMonth',
#        'AmountToCreditLimitRatio', 'IncomeToSpendingRatioZip',
#        'IncomeToSpendingRatioPerson', 'DebtToIncomeRatio', 'CardUsageRatio',
#        'YearsToRetirement', 'Account Age (Days)', 'Age Group', 'Is Retired',
#        'Bad PIN Error'],
#       dtype='object')

# %%
df = df.drop(["User", "Card", "Merchant Name", "Errors?", "Card Brand", "Acct Open Date", "Year PIN last Changed", "Birth Year", "Birth Month"], axis=1)
df.head(2)
# Out:
#       Amount           Use Chip   MCC Card Type  Has Chip  Cards Issued  \
# 6780  123.97  Swipe Transaction  5541     Debit         1             2
# 6781  123.97  Swipe Transaction  5541     Debit         1             2
#
#       Credit Limit  Current Age  Retirement Age  Gender  ...  \
# 6780       24295.0           53              66  Female  ...
# 6781       21968.0           53              66  Female  ...
#
#       AmountToCreditLimitRatio  IncomeToSpendingRatioZip  \
# 6780                  0.005103                236.170041
# 6781                  0.005643                236.170041
#
#       IncomeToSpendingRatioPerson  DebtToIncomeRatio  CardUsageRatio  \
# 6780                   481.535855           2.137714             2.5
# 6781                   481.535855           2.137714             2.5
#
#       YearsToRetirement  Account Age (Days) Age Group  Is Retired  \
# 6780                 13                5601     46-60       False
# 6781                 13                1371     46-60       False
#
#       Bad PIN Error
# 6780          False
# 6781          False
#
# [2 rows x 35 columns]

# %% [markdown]
# #### Save the Featured Data

# %%
df.to_parquet("../0 - Data/3 - featured/ft_strategy_1.pq")
