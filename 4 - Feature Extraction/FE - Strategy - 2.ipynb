# %% [markdown]
# ## Strategy
#
# #### INFO
#
# - End Columns: 35
# - Extracted Features: 9
#     - Hour
#     - DayOfWeek
#     - MonthOfYear
#     - Is Weekend
#     - Account Age (Days)
#     - DebtToIncomeRatio
#     - CreditUtilization
#     - Age Group
#     - Is Retired

# %%
import pandas as pd
import numpy as np

original_df = pd.read_parquet("../0 - Data/2 - Clean/clean_transactions.pq")
original_df.head()
# Out:
#    User  Card  Year  Month  Day  Amount          Use Chip  \
# 0     0     0  2018      1    2  130.95  Chip Transaction
# 1     0     0  2018      1    2  130.95  Chip Transaction
# 2     0     0  2018      1    2  130.95  Chip Transaction
# 3     0     0  2018      1    2  130.95  Chip Transaction
# 4     0     0  2018      1    2  130.95  Chip Transaction
#
#          Merchant Name Merchant City Merchant State  ... Zipcode  Latitude  \
# 0  5817218446178736267      La Verne             CA  ...   91750     34.15
# 1  5817218446178736267      La Verne             CA  ...   91750     34.15
# 2  5817218446178736267      La Verne             CA  ...   91750     34.15
# 3  5817218446178736267      La Verne             CA  ...   91750     34.15
# 4  5817218446178736267      La Verne             CA  ...   91750     34.15
#
#   Longitude  Per Capita Income - Zipcode Yearly Income - Person Total Debt  \
# 0   -117.76                      29278.0                59696.0   127613.0
# 1   -117.76                      29278.0                59696.0   127613.0
# 2   -117.76                      29278.0                59696.0   127613.0
# 3   -117.76                      29278.0                59696.0   127613.0
# 4   -117.76                      29278.0                59696.0   127613.0
#
#    FICO Score Num Credit Cards            Datetime  Is Fraud
# 0         787                5 2018-01-02 06:28:00         0
# 1         787                5 2018-01-02 06:28:00         0
# 2         787                5 2018-01-02 06:28:00         0
# 3         787                5 2018-01-02 06:28:00         0
# 4         787                5 2018-01-02 06:28:00         0
#
# [5 rows x 45 columns]

# %% [markdown]
# #### Drop Unnecessary Columns

# %%
# Columns to drop
columns_to_drop = [
    "User", "Card", "Merchant Name", "Merchant State", "Merchant City", "Person", "Zip", "CARD INDEX", "Card Number", 
    "CVV", "Expires", "Address", "Apartment", "City", "State", "Zipcode", "Errors?", 
    "Card on Dark Web"
]

df = original_df.drop(columns_to_drop, axis=1)
df.head()
# Out:
#    Year  Month  Day  Amount          Use Chip   MCC  Card Brand  \
# 0  2018      1    2  130.95  Chip Transaction  5912        Visa
# 1  2018      1    2  130.95  Chip Transaction  5912        Visa
# 2  2018      1    2  130.95  Chip Transaction  5912        Visa
# 3  2018      1    2  130.95  Chip Transaction  5912        Visa
# 4  2018      1    2  130.95  Chip Transaction  5912  Mastercard
#
#          Card Type  Has Chip  Cards Issued  ...  Gender Latitude  Longitude  \
# 0            Debit         1             2  ...  Female    34.15    -117.76
# 1            Debit         1             2  ...  Female    34.15    -117.76
# 2            Debit         1             2  ...  Female    34.15    -117.76
# 3           Credit         0             1  ...  Female    34.15    -117.76
# 4  Debit (Prepaid)         1             1  ...  Female    34.15    -117.76
#
#    Per Capita Income - Zipcode  Yearly Income - Person  Total Debt  \
# 0                      29278.0                 59696.0    127613.0
# 1                      29278.0                 59696.0    127613.0
# 2                      29278.0                 59696.0    127613.0
# 3                      29278.0                 59696.0    127613.0
# 4                      29278.0                 59696.0    127613.0
#
#    FICO Score Num Credit Cards            Datetime  Is Fraud
# 0         787                5 2018-01-02 06:28:00         0
# 1         787                5 2018-01-02 06:28:00         0
# 2         787                5 2018-01-02 06:28:00         0
# 3         787                5 2018-01-02 06:28:00         0
# 4         787                5 2018-01-02 06:28:00         0
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Time Features Extraction

# %%
df['Hour'] = df['Datetime'].dt.hour
df['MonthOfYear'] = df['Datetime'].dt.month
df['DayOfWeek'] = df['Datetime'].dt.dayofweek  # 0 is Monday, 6 is Sunday
df['Is Weekend'] = df['DayOfWeek'].apply(lambda x: 1 if x >= 5 else 0)
df.head()
# Out:
#    Year  Month  Day  Amount          Use Chip   MCC  Card Brand  \
# 0  2018      1    2  130.95  Chip Transaction  5912        Visa
# 1  2018      1    2  130.95  Chip Transaction  5912        Visa
# 2  2018      1    2  130.95  Chip Transaction  5912        Visa
# 3  2018      1    2  130.95  Chip Transaction  5912        Visa
# 4  2018      1    2  130.95  Chip Transaction  5912  Mastercard
#
#          Card Type  Has Chip  Cards Issued  ...  Total Debt FICO Score  \
# 0            Debit         1             2  ...    127613.0        787
# 1            Debit         1             2  ...    127613.0        787
# 2            Debit         1             2  ...    127613.0        787
# 3           Credit         0             1  ...    127613.0        787
# 4  Debit (Prepaid)         1             1  ...    127613.0        787
#
#    Num Credit Cards            Datetime  Is Fraud  Transaction Hour  \
# 0                 5 2018-01-02 06:28:00         0                 6
# 1                 5 2018-01-02 06:28:00         0                 6
# 2                 5 2018-01-02 06:28:00         0                 6
# 3                 5 2018-01-02 06:28:00         0                 6
# 4                 5 2018-01-02 06:28:00         0                 6
#
#    Transaction Day Transaction Month  Transaction Day of Week  Is Weekend
# 0                2                 1                        1           0
# 1                2                 1                        1           0
# 2                2                 1                        1           0
# 3                2                 1                        1           0
# 4                2                 1                        1           0
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Account Age

# %%
# Convert 'Acct Open Date' to datetime if it is not already
df['Acct Open Date'] = pd.to_datetime(df['Acct Open Date'])

# Calculate account age in days at the time of the transaction
df['Account Age (Days)'] = (df['Datetime'] - df['Acct Open Date']).dt.days

df.head()
# Out:
#    Year  Month  Day  Amount          Use Chip   MCC  Card Brand  \
# 0  2018      1    2  130.95  Chip Transaction  5912        Visa
# 1  2018      1    2  130.95  Chip Transaction  5912        Visa
# 2  2018      1    2  130.95  Chip Transaction  5912        Visa
# 3  2018      1    2  130.95  Chip Transaction  5912        Visa
# 4  2018      1    2  130.95  Chip Transaction  5912  Mastercard
#
#          Card Type  Has Chip  Cards Issued  ...  FICO Score Num Credit Cards  \
# 0            Debit         1             2  ...         787                5
# 1            Debit         1             2  ...         787                5
# 2            Debit         1             2  ...         787                5
# 3           Credit         0             1  ...         787                5
# 4  Debit (Prepaid)         1             1  ...         787                5
#
#              Datetime  Is Fraud  Transaction Hour  Transaction Day  \
# 0 2018-01-02 06:28:00         0                 6                2
# 1 2018-01-02 06:28:00         0                 6                2
# 2 2018-01-02 06:28:00         0                 6                2
# 3 2018-01-02 06:28:00         0                 6                2
# 4 2018-01-02 06:28:00         0                 6                2
#
#    Transaction Month Transaction Day of Week  Is Weekend  Account Age (Days)
# 0                  1                       1           0                5602
# 1                  1                       1           0                1372
# 2                  1                       1           0                5299
# 3                  1                       1           0                5480
# 4                  1                       1           0                3410
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Debt to Income Ratio

# %%
df['Debt to Income Ratio'] = df['Total Debt'] / df['Yearly Income - Person']
df.head()
# Out:
#    Year  Month  Day  Amount          Use Chip   MCC  Card Brand  \
# 0  2018      1    2  130.95  Chip Transaction  5912        Visa
# 1  2018      1    2  130.95  Chip Transaction  5912        Visa
# 2  2018      1    2  130.95  Chip Transaction  5912        Visa
# 3  2018      1    2  130.95  Chip Transaction  5912        Visa
# 4  2018      1    2  130.95  Chip Transaction  5912  Mastercard
#
#          Card Type  Has Chip  Cards Issued  ...  Num Credit Cards  \
# 0            Debit         1             2  ...                 5
# 1            Debit         1             2  ...                 5
# 2            Debit         1             2  ...                 5
# 3           Credit         0             1  ...                 5
# 4  Debit (Prepaid)         1             1  ...                 5
#
#              Datetime  Is Fraud  Transaction Hour  Transaction Day  \
# 0 2018-01-02 06:28:00         0                 6                2
# 1 2018-01-02 06:28:00         0                 6                2
# 2 2018-01-02 06:28:00         0                 6                2
# 3 2018-01-02 06:28:00         0                 6                2
# 4 2018-01-02 06:28:00         0                 6                2
#
#    Transaction Month  Transaction Day of Week Is Weekend  Account Age (Days)  \
# 0                  1                        1          0                5602
# 1                  1                        1          0                1372
# 2                  1                        1          0                5299
# 3                  1                        1          0                5480
# 4                  1                        1          0                3410
#
#    Debt to Income Ratio
# 0              2.137714
# 1              2.137714
# 2              2.137714
# 3              2.137714
# 4              2.137714
#
# [5 rows x 34 columns]

# %% [markdown]
# #### Credit Utilization

# %%
df['Credit Utilization'] = np.where(df['Credit Limit'] == 0, 1, df['Amount'] / df['Credit Limit'])
df.head()
# Out:
#    Year  Month  Day  Amount          Use Chip   MCC  Card Brand  \
# 0  2018      1    2  130.95  Chip Transaction  5912        Visa
# 1  2018      1    2  130.95  Chip Transaction  5912        Visa
# 2  2018      1    2  130.95  Chip Transaction  5912        Visa
# 3  2018      1    2  130.95  Chip Transaction  5912        Visa
# 4  2018      1    2  130.95  Chip Transaction  5912  Mastercard
#
#          Card Type  Has Chip  Cards Issued  ...            Datetime Is Fraud  \
# 0            Debit         1             2  ... 2018-01-02 06:28:00        0
# 1            Debit         1             2  ... 2018-01-02 06:28:00        0
# 2            Debit         1             2  ... 2018-01-02 06:28:00        0
# 3           Credit         0             1  ... 2018-01-02 06:28:00        0
# 4  Debit (Prepaid)         1             1  ... 2018-01-02 06:28:00        0
#
#    Transaction Hour  Transaction Day  Transaction Month  \
# 0                 6                2                  1
# 1                 6                2                  1
# 2                 6                2                  1
# 3                 6                2                  1
# 4                 6                2                  1
#
#    Transaction Day of Week  Is Weekend Account Age (Days)  \
# 0                        1           0               5602
# 1                        1           0               1372
# 2                        1           0               5299
# 3                        1           0               5480
# 4                        1           0               3410
#
#    Debt to Income Ratio  Credit Utilization
# 0              2.137714            0.005390
# 1              2.137714            0.005961
# 2              2.137714            0.002821
# 3              2.137714            0.010560
# 4              2.137714            4.676786
#
# [5 rows x 35 columns]

# %% [markdown]
# #### Age Groups

# %%
df['Age Group'] = pd.cut(df['Current Age'], bins=[0, 25, 35, 45, 60, 100], labels=['18-25', '26-35', '36-45', '46-60', '60+'])
df.head()
# Out:
#    Year  Month  Day  Amount          Use Chip   MCC  Card Brand  \
# 0  2018      1    2  130.95  Chip Transaction  5912        Visa
# 1  2018      1    2  130.95  Chip Transaction  5912        Visa
# 2  2018      1    2  130.95  Chip Transaction  5912        Visa
# 3  2018      1    2  130.95  Chip Transaction  5912        Visa
# 4  2018      1    2  130.95  Chip Transaction  5912  Mastercard
#
#          Card Type  Has Chip  Cards Issued  ...  Is Fraud Transaction Hour  \
# 0            Debit         1             2  ...         0                6
# 1            Debit         1             2  ...         0                6
# 2            Debit         1             2  ...         0                6
# 3           Credit         0             1  ...         0                6
# 4  Debit (Prepaid)         1             1  ...         0                6
#
#    Transaction Day  Transaction Month  Transaction Day of Week  Is Weekend  \
# 0                2                  1                        1           0
# 1                2                  1                        1           0
# 2                2                  1                        1           0
# 3                2                  1                        1           0
# 4                2                  1                        1           0
#
#    Account Age (Days) Debt to Income Ratio  Credit Utilization  Age Group
# 0                5602             2.137714            0.005390      46-60
# 1                1372             2.137714            0.005961      46-60
# 2                5299             2.137714            0.002821      46-60
# 3                5480             2.137714            0.010560      46-60
# 4                3410             2.137714            4.676786      46-60
#
# [5 rows x 36 columns]

# %% [markdown]
# #### Retirement

# %%
df['Is Retired'] = df['Current Age'] >= df['Retirement Age']
df.head()
# Out:
#    Year  Month  Day  Amount          Use Chip   MCC  Card Brand  \
# 0  2018      1    2  130.95  Chip Transaction  5912        Visa
# 1  2018      1    2  130.95  Chip Transaction  5912        Visa
# 2  2018      1    2  130.95  Chip Transaction  5912        Visa
# 3  2018      1    2  130.95  Chip Transaction  5912        Visa
# 4  2018      1    2  130.95  Chip Transaction  5912  Mastercard
#
#          Card Type  Has Chip  Cards Issued  ...  Transaction Hour  \
# 0            Debit         1             2  ...                 6
# 1            Debit         1             2  ...                 6
# 2            Debit         1             2  ...                 6
# 3           Credit         0             1  ...                 6
# 4  Debit (Prepaid)         1             1  ...                 6
#
#   Transaction Day  Transaction Month  Transaction Day of Week  Is Weekend  \
# 0               2                  1                        1           0
# 1               2                  1                        1           0
# 2               2                  1                        1           0
# 3               2                  1                        1           0
# 4               2                  1                        1           0
#
#    Account Age (Days)  Debt to Income Ratio Credit Utilization  Age Group  \
# 0                5602              2.137714           0.005390      46-60
# 1                1372              2.137714           0.005961      46-60
# 2                5299              2.137714           0.002821      46-60
# 3                5480              2.137714           0.010560      46-60
# 4                3410              2.137714           4.676786      46-60
#
#    Is Retired
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#
# [5 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Amount', 'Use Chip', 'MCC', 'Card Brand',
#        'Card Type', 'Has Chip', 'Cards Issued', 'Credit Limit',
#        'Acct Open Date', 'Year PIN last Changed', 'Current Age',
#        'Retirement Age', 'Birth Year', 'Birth Month', 'Gender', 'Latitude',
#        'Longitude', 'Per Capita Income - Zipcode', 'Yearly Income - Person',
#        'Total Debt', 'FICO Score', 'Num Credit Cards', 'Datetime', 'Is Fraud',
#        'Transaction Hour', 'Transaction Day', 'Transaction Month',
#        'Transaction Day of Week', 'Is Weekend', 'Account Age (Days)',
#        'Debt to Income Ratio', 'Credit Utilization', 'Age Group',
#        'Is Retired'],
#       dtype='object')

# %% [markdown]
# #### Save the Featured Data

# %%
# df.to_parquet("../0 - Data/featured_transactions.pq")
