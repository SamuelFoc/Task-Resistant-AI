# %%
import pandas as pd
import numpy as np

original_df = pd.read_parquet("../0 - Data/cleaned_transactions.pq")
original_df.head()
# Out:
#    User  Card  Amount          Use Chip        Merchant Name Merchant City  \
# 0     0     0  130.95  Chip Transaction  5817218446178736267      La Verne
# 1     0     0  130.95  Chip Transaction  5817218446178736267      La Verne
# 2     0     0  130.95  Chip Transaction  5817218446178736267      La Verne
# 3     0     0  130.95  Chip Transaction  5817218446178736267      La Verne
# 4     0     0  130.95  Chip Transaction  5817218446178736267      La Verne
#
#   Merchant State      Zip   MCC Errors?  ...  Zipcode Latitude Longitude  \
# 0             CA  91750.0  5912       0  ...    91750    34.15   -117.76
# 1             CA  91750.0  5912       0  ...    91750    34.15   -117.76
# 2             CA  91750.0  5912       0  ...    91750    34.15   -117.76
# 3             CA  91750.0  5912       0  ...    91750    34.15   -117.76
# 4             CA  91750.0  5912       0  ...    91750    34.15   -117.76
#
#    Per Capita Income - Zipcode Yearly Income - Person  Total Debt  FICO Score  \
# 0                      29278.0                59696.0    127613.0         787
# 1                      29278.0                59696.0    127613.0         787
# 2                      29278.0                59696.0    127613.0         787
# 3                      29278.0                59696.0    127613.0         787
# 4                      29278.0                59696.0    127613.0         787
#
#    Num Credit Cards            Datetime Is Fraud
# 0                 5 2018-01-02 06:28:00        0
# 1                 5 2018-01-02 06:28:00        0
# 2                 5 2018-01-02 06:28:00        0
# 3                 5 2018-01-02 06:28:00        0
# 4                 5 2018-01-02 06:28:00        0
#
# [5 rows x 42 columns]

# %% [markdown]
# #### Drop Unnecessary Columns

# %%
# Columns to drop
columns_to_drop = [
    "User", "Card", "Merchant Name", "Merchant State", "Merchant City", "Person", "Zip", "CARD INDEX", "Card Number", 
    "CVV", "Expires", "Address", "Apartment", "City", "State", "Zipcode", "Errors?", 
    "Card on Dark Web"
]

df = original_df.drop(columns_to_drop, axis=1)
df.head()
# Out:
#    Amount          Use Chip   MCC  Card Brand        Card Type  Has Chip  \
# 0  130.95  Chip Transaction  5912        Visa            Debit         1
# 1  130.95  Chip Transaction  5912        Visa            Debit         1
# 2  130.95  Chip Transaction  5912        Visa            Debit         1
# 3  130.95  Chip Transaction  5912        Visa           Credit         0
# 4  130.95  Chip Transaction  5912  Mastercard  Debit (Prepaid)         1
#
#    Cards Issued  Credit Limit Acct Open Date  Year PIN last Changed  ...  \
# 0             2       24295.0     2002-09-01                   2008  ...
# 1             2       21968.0     2014-04-01                   2014  ...
# 2             2       46414.0     2003-07-01                   2004  ...
# 3             1       12400.0     2003-01-01                   2012  ...
# 4             1          28.0     2008-09-01                   2009  ...
#
#    Gender  Latitude  Longitude  Per Capita Income - Zipcode  \
# 0  Female     34.15    -117.76                      29278.0
# 1  Female     34.15    -117.76                      29278.0
# 2  Female     34.15    -117.76                      29278.0
# 3  Female     34.15    -117.76                      29278.0
# 4  Female     34.15    -117.76                      29278.0
#
#   Yearly Income - Person  Total Debt  FICO Score  Num Credit Cards  \
# 0                59696.0    127613.0         787                 5
# 1                59696.0    127613.0         787                 5
# 2                59696.0    127613.0         787                 5
# 3                59696.0    127613.0         787                 5
# 4                59696.0    127613.0         787                 5
#
#              Datetime  Is Fraud
# 0 2018-01-02 06:28:00         0
# 1 2018-01-02 06:28:00         0
# 2 2018-01-02 06:28:00         0
# 3 2018-01-02 06:28:00         0
# 4 2018-01-02 06:28:00         0
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Time Features Extraction

# %%
df['Transaction Hour'] = df['Datetime'].dt.hour
df['Transaction Day'] = df['Datetime'].dt.day
df['Transaction Month'] = df['Datetime'].dt.month
df['Transaction Day of Week'] = df['Datetime'].dt.dayofweek  # 0 is Monday, 6 is Sunday
df['Is Weekend'] = df['Transaction Day of Week'].apply(lambda x: 1 if x >= 5 else 0)
df.head()
# Out:
#    Amount          Use Chip   MCC  Card Brand        Card Type  Has Chip  \
# 0  130.95  Chip Transaction  5912        Visa            Debit         1
# 1  130.95  Chip Transaction  5912        Visa            Debit         1
# 2  130.95  Chip Transaction  5912        Visa            Debit         1
# 3  130.95  Chip Transaction  5912        Visa           Credit         0
# 4  130.95  Chip Transaction  5912  Mastercard  Debit (Prepaid)         1
#
#    Cards Issued  Credit Limit Acct Open Date  Year PIN last Changed  ...  \
# 0             2       24295.0     2002-09-01                   2008  ...
# 1             2       21968.0     2014-04-01                   2014  ...
# 2             2       46414.0     2003-07-01                   2004  ...
# 3             1       12400.0     2003-01-01                   2012  ...
# 4             1          28.0     2008-09-01                   2009  ...
#
#    Total Debt  FICO Score  Num Credit Cards            Datetime Is Fraud  \
# 0    127613.0         787                 5 2018-01-02 06:28:00        0
# 1    127613.0         787                 5 2018-01-02 06:28:00        0
# 2    127613.0         787                 5 2018-01-02 06:28:00        0
# 3    127613.0         787                 5 2018-01-02 06:28:00        0
# 4    127613.0         787                 5 2018-01-02 06:28:00        0
#
#    Transaction Hour  Transaction Day  Transaction Month  \
# 0                 6                2                  1
# 1                 6                2                  1
# 2                 6                2                  1
# 3                 6                2                  1
# 4                 6                2                  1
#
#    Transaction Day of Week  Is Weekend
# 0                        1           0
# 1                        1           0
# 2                        1           0
# 3                        1           0
# 4                        1           0
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Account Age

# %%
# Convert 'Acct Open Date' to datetime if it is not already
df['Acct Open Date'] = pd.to_datetime(df['Acct Open Date'])

# Calculate account age in days at the time of the transaction
df['Account Age (Days)'] = (df['Datetime'] - df['Acct Open Date']).dt.days

df.head()
# Out:
#    Amount          Use Chip   MCC  Card Brand        Card Type  Has Chip  \
# 0  130.95  Chip Transaction  5912        Visa            Debit         1
# 1  130.95  Chip Transaction  5912        Visa            Debit         1
# 2  130.95  Chip Transaction  5912        Visa            Debit         1
# 3  130.95  Chip Transaction  5912        Visa           Credit         0
# 4  130.95  Chip Transaction  5912  Mastercard  Debit (Prepaid)         1
#
#    Cards Issued  Credit Limit Acct Open Date  Year PIN last Changed  ...  \
# 0             2       24295.0     2002-09-01                   2008  ...
# 1             2       21968.0     2014-04-01                   2014  ...
# 2             2       46414.0     2003-07-01                   2004  ...
# 3             1       12400.0     2003-01-01                   2012  ...
# 4             1          28.0     2008-09-01                   2009  ...
#
#    FICO Score  Num Credit Cards            Datetime  Is Fraud  \
# 0         787                 5 2018-01-02 06:28:00         0
# 1         787                 5 2018-01-02 06:28:00         0
# 2         787                 5 2018-01-02 06:28:00         0
# 3         787                 5 2018-01-02 06:28:00         0
# 4         787                 5 2018-01-02 06:28:00         0
#
#   Transaction Hour  Transaction Day  Transaction Month  \
# 0                6                2                  1
# 1                6                2                  1
# 2                6                2                  1
# 3                6                2                  1
# 4                6                2                  1
#
#    Transaction Day of Week  Is Weekend  Account Age (Days)
# 0                        1           0                5602
# 1                        1           0                1372
# 2                        1           0                5299
# 3                        1           0                5480
# 4                        1           0                3410
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Debt to Income Ratio

# %%
df['Debt to Income Ratio'] = df['Total Debt'] / df['Yearly Income - Person']
df.head()
# Out:
#    Amount          Use Chip   MCC  Card Brand        Card Type  Has Chip  \
# 0  130.95  Chip Transaction  5912        Visa            Debit         1
# 1  130.95  Chip Transaction  5912        Visa            Debit         1
# 2  130.95  Chip Transaction  5912        Visa            Debit         1
# 3  130.95  Chip Transaction  5912        Visa           Credit         0
# 4  130.95  Chip Transaction  5912  Mastercard  Debit (Prepaid)         1
#
#    Cards Issued  Credit Limit Acct Open Date  Year PIN last Changed  ...  \
# 0             2       24295.0     2002-09-01                   2008  ...
# 1             2       21968.0     2014-04-01                   2014  ...
# 2             2       46414.0     2003-07-01                   2004  ...
# 3             1       12400.0     2003-01-01                   2012  ...
# 4             1          28.0     2008-09-01                   2009  ...
#
#    Num Credit Cards            Datetime  Is Fraud  Transaction Hour  \
# 0                 5 2018-01-02 06:28:00         0                 6
# 1                 5 2018-01-02 06:28:00         0                 6
# 2                 5 2018-01-02 06:28:00         0                 6
# 3                 5 2018-01-02 06:28:00         0                 6
# 4                 5 2018-01-02 06:28:00         0                 6
#
#   Transaction Day  Transaction Month  Transaction Day of Week  Is Weekend  \
# 0               2                  1                        1           0
# 1               2                  1                        1           0
# 2               2                  1                        1           0
# 3               2                  1                        1           0
# 4               2                  1                        1           0
#
#    Account Age (Days)  Debt to Income Ratio
# 0                5602              2.137714
# 1                1372              2.137714
# 2                5299              2.137714
# 3                5480              2.137714
# 4                3410              2.137714
#
# [5 rows x 31 columns]

# %% [markdown]
# #### Credit Utilization

# %%
df['Credit Utilization'] = np.where(df['Credit Limit'] == 0, 1, df['Amount'] / df['Credit Limit'])
df.head()
# Out:
#    Amount          Use Chip   MCC  Card Brand        Card Type  Has Chip  \
# 0  130.95  Chip Transaction  5912        Visa            Debit         1
# 1  130.95  Chip Transaction  5912        Visa            Debit         1
# 2  130.95  Chip Transaction  5912        Visa            Debit         1
# 3  130.95  Chip Transaction  5912        Visa           Credit         0
# 4  130.95  Chip Transaction  5912  Mastercard  Debit (Prepaid)         1
#
#    Cards Issued  Credit Limit Acct Open Date  Year PIN last Changed  ...  \
# 0             2       24295.0     2002-09-01                   2008  ...
# 1             2       21968.0     2014-04-01                   2014  ...
# 2             2       46414.0     2003-07-01                   2004  ...
# 3             1       12400.0     2003-01-01                   2012  ...
# 4             1          28.0     2008-09-01                   2009  ...
#
#              Datetime  Is Fraud  Transaction Hour  Transaction Day  \
# 0 2018-01-02 06:28:00         0                 6                2
# 1 2018-01-02 06:28:00         0                 6                2
# 2 2018-01-02 06:28:00         0                 6                2
# 3 2018-01-02 06:28:00         0                 6                2
# 4 2018-01-02 06:28:00         0                 6                2
#
#   Transaction Month  Transaction Day of Week  Is Weekend  Account Age (Days)  \
# 0                 1                        1           0                5602
# 1                 1                        1           0                1372
# 2                 1                        1           0                5299
# 3                 1                        1           0                5480
# 4                 1                        1           0                3410
#
#    Debt to Income Ratio  Credit Utilization
# 0              2.137714            0.005390
# 1              2.137714            0.005961
# 2              2.137714            0.002821
# 3              2.137714            0.010560
# 4              2.137714            4.676786
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Age Groups

# %%
df['Age Group'] = pd.cut(df['Current Age'], bins=[0, 25, 35, 45, 60, 100], labels=['18-25', '26-35', '36-45', '46-60', '60+'])
df.head()
# Out:
#    Amount          Use Chip   MCC  Card Brand        Card Type  Has Chip  \
# 0  130.95  Chip Transaction  5912        Visa            Debit         1
# 1  130.95  Chip Transaction  5912        Visa            Debit         1
# 2  130.95  Chip Transaction  5912        Visa            Debit         1
# 3  130.95  Chip Transaction  5912        Visa           Credit         0
# 4  130.95  Chip Transaction  5912  Mastercard  Debit (Prepaid)         1
#
#    Cards Issued  Credit Limit Acct Open Date  Year PIN last Changed  ...  \
# 0             2       24295.0     2002-09-01                   2008  ...
# 1             2       21968.0     2014-04-01                   2014  ...
# 2             2       46414.0     2003-07-01                   2004  ...
# 3             1       12400.0     2003-01-01                   2012  ...
# 4             1          28.0     2008-09-01                   2009  ...
#
#    Is Fraud  Transaction Hour  Transaction Day  Transaction Month  \
# 0         0                 6                2                  1
# 1         0                 6                2                  1
# 2         0                 6                2                  1
# 3         0                 6                2                  1
# 4         0                 6                2                  1
#
#   Transaction Day of Week  Is Weekend  Account Age (Days)  \
# 0                       1           0                5602
# 1                       1           0                1372
# 2                       1           0                5299
# 3                       1           0                5480
# 4                       1           0                3410
#
#    Debt to Income Ratio  Credit Utilization  Age Group
# 0              2.137714            0.005390      46-60
# 1              2.137714            0.005961      46-60
# 2              2.137714            0.002821      46-60
# 3              2.137714            0.010560      46-60
# 4              2.137714            4.676786      46-60
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Retirement

# %%
df['Is Retired'] = df['Current Age'] >= df['Retirement Age']
df.head()
# Out:
#    Amount          Use Chip   MCC  Card Brand        Card Type  Has Chip  \
# 0  130.95  Chip Transaction  5912        Visa            Debit         1
# 1  130.95  Chip Transaction  5912        Visa            Debit         1
# 2  130.95  Chip Transaction  5912        Visa            Debit         1
# 3  130.95  Chip Transaction  5912        Visa           Credit         0
# 4  130.95  Chip Transaction  5912  Mastercard  Debit (Prepaid)         1
#
#    Cards Issued  Credit Limit Acct Open Date  Year PIN last Changed  ...  \
# 0             2       24295.0     2002-09-01                   2008  ...
# 1             2       21968.0     2014-04-01                   2014  ...
# 2             2       46414.0     2003-07-01                   2004  ...
# 3             1       12400.0     2003-01-01                   2012  ...
# 4             1          28.0     2008-09-01                   2009  ...
#
#    Transaction Hour  Transaction Day  Transaction Month  \
# 0                 6                2                  1
# 1                 6                2                  1
# 2                 6                2                  1
# 3                 6                2                  1
# 4                 6                2                  1
#
#    Transaction Day of Week Is Weekend  Account Age (Days)  \
# 0                        1          0                5602
# 1                        1          0                1372
# 2                        1          0                5299
# 3                        1          0                5480
# 4                        1          0                3410
#
#    Debt to Income Ratio  Credit Utilization  Age Group  Is Retired
# 0              2.137714            0.005390      46-60       False
# 1              2.137714            0.005961      46-60       False
# 2              2.137714            0.002821      46-60       False
# 3              2.137714            0.010560      46-60       False
# 4              2.137714            4.676786      46-60       False
#
# [5 rows x 34 columns]

# %% [markdown]
# #### Save the Featured Data

# %%
df.to_parquet("../0 - Data/featured_transactions.pq")
